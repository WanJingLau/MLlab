# %% [markdown]
# # Lab 1

# %%
print("This is code cell")
# Out:
# This is code cell

# %%
# print statements
variable = "right in the strings!"
print(f"f strings allow you to embed variables {variable}")
# Out:
# f strings allow you to embed variables right in the strings!

# %% [markdown]
# # Week 2 Lab

# %%
import numpy as np
import matplotlib.pyplot as plt

# data stored
x_train = np.array([1.0, 2.0]) #input variable, size in 1000 sqft
y_train = np.array([300.0, 500.0]) #target, price in 1000 sqft of dollars

print(f"x_train = {x_train}")
print(f"y_train = {y_train}")
# Out:
# x_train = [1. 2.]
# y_train = [300. 500.]

# %%
# m is the number of training examples
print(f"x_train.shape : {x_train.shape}")
m = x_train.shape[0]
print(f"Number of training examples is:{m}")
# Out:
# x_train.shape : (2,)
# Number of training examples is:2

# %%
m = len(x_train)
print(f"Number of training examples is:{m}")
# Out:
# Number of training examples is:2

# %%
i = 0 #change this to 1 to see(x^1,y^1), as a number of per 1000

x_i = x_train[i]
y_i = y_train[i]

print(f"(x^({i}), y^({i})) = ({x_i}, {y_i})")
# Out:
# (x^(0), y^(0)) = (1.0, 300.0)

# %% [markdown]
# # Plotting the data

# %%
plt.scatter(x_train, y_train, marker='x', c='r')

#set title
plt.title("Housing Prices")

#set y-axis label
plt.ylabel('Price (in 1000s of dollars)')

#set x-axis label
plt.xlabel('Size (1000sqft)')

plt.show()

# %%
w = 200
b = 100
print(f"w:{w}")
print(f"b:{b}")
# Out:
# w:200
# b:100

# %%
def compute_model_output(x, w, b):
    m = x.shape[0] #shape give us how many x we have, can also use len
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w * x[i] + b
    return f_wb

# %%
tmp_f_wb = compute_model_output(x_train, w, b,)
# Plot our model prediction
plt.plot(x_train, tmp_f_wb, c='b',label='Our Prediction')
# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r',label='Actual Values')
# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show() #result doesnot fit the data

# %% [markdown]
# # Prediction

# %%
w = 200
b = 100
x_i = 1.2
cost_1200sqft = w * x_i +b
print(f"${cost_1200sqft:.0f} thousand dollars")
# Out:
# $340 thousand dollars
